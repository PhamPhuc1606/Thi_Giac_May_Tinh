# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
my_path = 'D:/Anh/anh1.jpg'
im = Image.open(my_path)
plt.imshow(im)

# %%
im_gray = im.convert('L')
plt.imshow(im_gray, cmap='gray')

# %%
im_array = np.array(im_gray)
print(im_array)
# Out:
# [[201 198 199 ... 171 170 168]
#  [206 199 197 ... 171 169 167]
#  [208 194 187 ... 171 168 166]
#  ...
#  [146 121 102 ...  34  34  34]
#  [136 134 138 ...  30  30  31]
#  [ 83  85  96 ...  21  21  22]]

# %%
plt.figure()
plt.hist(im_array.flatten(), bins=128)
plt.title('Biểu đồ Histogram của ảnh')
plt.xlabel('Giá trị của pixel')
plt.ylabel('Số lượng')
plt.show()

# %%
plt.figure()
plt.gray()
plt.contour(im_gray, origin="image")
plt.show()

# %%
my_path = 'D:/Anh/anh1.jpg'
im = Image.open(my_path).convert("L")
plt.imshow(im)
plt.figure()
plt.gray()
plt.contour(im, origin="image")
plt.axis('equal')
plt.show()
